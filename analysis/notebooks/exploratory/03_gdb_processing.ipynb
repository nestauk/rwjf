# %% [markdown]
# # Processing GDB
#
# The grants database is fairly harmonised, but there are some
#
# ## Preamble

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Additional imports
import os
import ratelim
import re
import io
import urllib
import codecs
import bs4
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import OrderedDict

from datetime import datetime
from nltk.corpus import stopwords

from analysis.src.nlp.lda_pipeline import LdaPipeline, CleanTokenize
from analysis.src.data.readnwrite import get_data_dir
from analysis.src.data.data_utilities import dataframe_health_report

stop = stopwords.words('English')

# %%
# %matplotlib inline
# Open a standard set of directories

# Paths

# Get the top path
data_path = get_data_dir()
# Create the path for external data
ext_data = os.path.join(data_path, 'external')
# Raw data
raw_data = os.path.join(data_path, 'raw')
# And external data
proc_data = os.path.join(data_path, 'processed')
# And interim data
inter_data = os.path.join(data_path, 'interim')
# And figures
fig_path = os.path.join(data_path, 'figures')

# Get date for saving files
today = datetime.utcnow()

today_str = "_".join([str(x) for x in [today.year, today.month, today.day]])

# %%
gdb_df = pd.read_csv(os.path.join(raw_data, 'gdb.csv'))
# Out:
# /Users/grichardson/miniconda3/envs/rwjf/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,5,7,10,11,12,13,14,18,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gdb_df.head(2)
# Out:
#    gh_user_id gdb_dataset_id source_id           start_date  status  \
# 0         NaN            gtr       GDB  2009-04-01 00:00:00  Closed
# 1         NaN            gtr       GDB  2009-10-01 00:00:00  Closed
#
#   gh_user_creation_date                                        description  \
# 0                   NaN  The past decade has seen a renaissance in acce...
# 1                   NaN  Humans and animals are made up of millions of ...
#
#      funding                                             row_id currency  \
# 0  2313330.0  http://gtr.rcuk.ac.uk:80/gtr/api/projects/00C9...      GBP
# 1  1520860.0  http://gtr.rcuk.ac.uk:80/gtr/api/projects/00E4...      GBP
#
#         ...       cb_category_list cb_role end_date gh_valid_description  \
# 0       ...                    NaN     NaN      NaN                  NaN
# 1       ...                    NaN     NaN      NaN                  NaN
#
#                         name administrative_area_level_1  \
# 0  University College London                     England
# 1  University College London                     England
#
#    administrative_area_level_2       lng        lat         country
# 0               Greater London -0.132718  51.524469  United Kingdom
# 1               Greater London -0.132718  51.524469  United Kingdom
#
# [2 rows x 23 columns]

# %%
health_gdb_df = dataframe_health_report(gdb_df, norm=True)

# %%
health_gdb_df
# Out:
#                                dtype non_null_count   null_count    NaN_count  \
# gh_user_id                   float64       0.098745     0.901255     0.901255
# gdb_dataset_id                object       0.672986     0.327014     0.327014
# source_id                     object              1            0            0
# start_date                    object        0.84556      0.15444      0.15444
# status                        object       0.566265     0.433735     0.433735
# gh_user_creation_date         object       0.098745     0.901255     0.901255
# description                   object       0.999993  6.81705e-06  6.81705e-06
# funding                       object       0.679046     0.320954     0.320954
# row_id                        object              1            0            0
# currency                      object        0.82247      0.17753      0.17753
# cb_category_group_list        object       0.142333     0.857667     0.857667
# gh_user_type                  object       0.098745     0.901255     0.901255
# cb_number_of_employees        object       0.228269     0.771731     0.771731
# cb_category_list              object       0.147507     0.852493     0.852493
# cb_role                       object       0.228269     0.771731     0.771731
# end_date                      object       0.409187     0.590813     0.590813
# gh_valid_description         float64       0.098745     0.901255     0.901255
# name                          object       0.996646   0.00335399   0.00335399
# administrative_area_level_1   object       0.645786     0.354214     0.354214
# administrative_area_level_2   object       0.522432     0.477568     0.477568
# lng                          float64       0.741532     0.258468     0.258468
# lat                          float64       0.741532     0.258468     0.258468
# country                       object       0.665201     0.334799     0.334799
#
#                             unique_values  \
# gh_user_id                          13827
# gdb_dataset_id                          7
# source_id                               3
# start_date                          22294
# status                                 14
# gh_user_creation_date               13827
# description                        102186
# funding                             54004
# row_id                             117285
# currency                                3
# cb_category_group_list               1921
# gh_user_type                            2
# cb_number_of_employees                 10
# cb_category_list                     6718
# cb_role                                 3
# end_date                             3870
# gh_valid_description                    1
# name                                67664
# administrative_area_level_1           844
# administrative_area_level_2          1710
# lng                                 17251
# lat                                 17370
# country                               163
#
#                                                                    modal_value  \
# gh_user_id                                                         1.19786e+07
# gdb_dataset_id                                                             gtr
# source_id                                                                  GDB
# start_date                                                          2017-01-01
# status                                                               operating
# gh_user_creation_date                                  2016-03-09 09:02:48 UTC
# description                  The Innovative Manufacturing and Construction ...
# funding                                                                  50000
# row_id                       http://gtr.rcuk.ac.uk:80/gtr/api/projects/FDEB...
# currency                                                                   USD
# cb_category_group_list                                             Health Care
# gh_user_type                                                               USR
# cb_number_of_employees                                                 unknown
# cb_category_list                                                   Health Care
# cb_role                                                                company
# end_date                                                         ="08/31/2015"
# gh_valid_description                                                         1
# name                                                 University College London
# administrative_area_level_1                                            England
# administrative_area_level_2                                     Greater London
# lng                                                                  -0.132718
# lat                                                                    51.5245
# country                                                          United States
#
#                             modal_value_count string_length_min  \
# gh_user_id                        0.000334035               NaN
# gdb_dataset_id                       0.184033                 3
# source_id                            0.672986                 3
# start_date                          0.0138522                 8
# status                               0.187967                 3
# gh_user_creation_date             0.000334035                23
# description                       0.000920302                 6
# funding                            0.00508552                 1
# row_id                            0.000920302                 6
# currency                             0.484474                 3
# cb_category_group_list              0.0520414                 6
# gh_user_type                        0.0907281                 3
# cb_number_of_employees              0.0742718                 4
# cb_category_list                    0.0212828                 3
# cb_role                              0.216114                 6
# end_date                           0.00788733                 8
# gh_valid_description                 0.098745               NaN
# name                                0.0107164                 1
# administrative_area_level_1          0.205295                 2
# administrative_area_level_2         0.0602968                 2
# lng                                 0.0107232               NaN
# lat                                 0.0107232               NaN
# country                              0.285846                 4
#
#                             string_length_max string_length_median  \
# gh_user_id                                NaN                  NaN
# gdb_dataset_id                             14                    4
# source_id                                  10                    3
# start_date                                 23                   13
# status                                     17                    6
# gh_user_creation_date                      23                   23
# description                              9811                 1745
# funding                                    15                    8
# row_id                                     78                   15
# currency                                    3                    3
# cb_category_group_list                    201                   18
# gh_user_type                                3                    3
# cb_number_of_employees                     10                    6
# cb_category_list                          299                   23
# cb_role                                     8                    7
# end_date                                   23                   13
# gh_valid_description                      NaN                  NaN
# name                                      149                   23
# administrative_area_level_1                52                    8
# administrative_area_level_2                49                   14
# lng                                       NaN                  NaN
# lat                                       NaN                  NaN
# country                                    32                   13
#
#                             string_empty_count
# gh_user_id                                 NaN
# gdb_dataset_id                               0
# source_id                                    0
# start_date                                   0
# status                                       0
# gh_user_creation_date                        0
# description                                  0
# funding                                      0
# row_id                                       0
# currency                                     0
# cb_category_group_list                       0
# gh_user_type                                 0
# cb_number_of_employees                       0
# cb_category_list                             0
# cb_role                                      0
# end_date                                     0
# gh_valid_description                       NaN
# name                                         0
# administrative_area_level_1                  0
# administrative_area_level_2                  0
# lng                                        NaN
# lat                                        NaN
# country                                      0

# %% [markdown]
# ## 1 Normalising
#
# ### 1.1 Dates

# %%
dates = []
for s in gdb_df['start_date']:
    if pd.isnull(s):
        dates.append(np.nan)
    else:
        dates.append(s.replace('"', '').replace('=', ''))
dates = pd.to_datetime(dates, infer_datetime_format=True, errors='coerce')

# %%
years = [d.year for d in dates]

# %%
gdb_dates_df = pd.DataFrame({'date': dates, 'year': years})

# %%
dataframe_health_report(gdb_dates_df)
# Out:
#                dtype non_null_count null_count NaN_count unique_values  \
# date  datetime64[ns]         124029      22662     22662         18894
# year         float64         124029      22662     22662           211
#
#      modal_value modal_value_count +inf_count -inf_count   min   max  \
# date         NaN                 0        NaN        NaN   NaN   NaN
# year        2015             17534          0          0  1744  2019
#
#      zeros_count    mean   25%   50%   75%
# date         NaN     NaN   NaN   NaN   NaN
# year           0  2010.7  2009  2013  2016

# %%
gdb_dates_df.to_csv(os.path.join(inter_data, 'gdb_dates.csv'), index=False)

# %% [markdown]
# ### 1.2 Funding Currency
#
# TODO: use `forex_python`

# %%
gdb_df['currency'].value_counts()
# Out:
# USD    71068
# GBP    32060
# EUR    17521
# Name: currency, dtype: int64

# %% [markdown]
# ## 2. Export

# %%
gdb_doc_ids = gdb_df.index.values
gdb_doc_id_df = pd.DataFrame({'doc_id': gdb_doc_ids})

# %%
gdb_doc_id_df.to_csv(os.path.join(inter_data, 'gdb_doc_ids.csv'),index=False)
